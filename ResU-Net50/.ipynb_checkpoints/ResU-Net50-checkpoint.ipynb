# %%
import numpy as np
import pandas as pd

from random import randint

import matplotlib.pyplot as plt
import gc
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

from sklearn.model_selection import train_test_split

from skimage.transform import resize

from keras.preprocessing.image import load_img
from keras import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import load_model
from keras.optimizers import Adam
from keras.utils.vis_utils import plot_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout,BatchNormalization
from keras.layers import Conv2D, Concatenate, MaxPooling2D
from keras.layers import UpSampling2D, Dropout, BatchNormalization
from tqdm import tqdm_notebook
from keras import initializers
from keras import regularizers
from keras import constraints
from keras.utils import conv_utils
from keras.utils.data_utils import get_file
from keras.engine.topology import get_source_inputs
from keras.engine import InputSpec
from keras import backend as K
from keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow as tf

from keras.applications.vgg16 import VGG16
from keras.engine.topology import Input
from keras.engine.training import Model
from keras.layers.convolutional import Conv2D, UpSampling2D, Conv2DTranspose
from keras.layers.core import Activation, SpatialDropout2D
from keras.layers.merge import concatenate
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D
# Out:
# C:\Users\Natthawat\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Helper

# %%
img_size_ori = 101
img_size_target = 128

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    #res = np.zeros((img_size_target, img_size_target), dtype=img.dtype)
    #res[:img_size_ori, :img_size_ori] = img
    #return res
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
    #return img[:img_size_ori, :img_size_ori]

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv("../data/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../data/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

# %%
train_df["images"] = [np.array(load_img("../data/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df["masks"] = [np.array(load_img("../data/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %% [markdown]
# # Calculate Coverage

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

# %%
def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
max_images = 60
grid_width = 15
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width, grid_height))
for i, idx in enumerate(train_df.index[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.text(1, img_size_ori-1, train_df.loc[idx].z, color="black")
    ax.text(img_size_ori - 1, 1, round(train_df.loc[idx].coverage, 2), color="black", ha="right", va="top")
    ax.text(1, 1, train_df.loc[idx].coverage_class, color="black", ha="left", va="top")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.suptitle("Green: salt. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")
# Out:
# Text(0.5,0.98,'Green: salt. Top-left: coverage class, top-right: salt coverage, bottom-left: depth')

# %% [markdown]
# # Create train/validation split stratified by salt coverage

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, stratify=train_df.coverage_class, random_state=1337)

# %%
tmp_img = np.zeros((img_size_target, img_size_target), dtype=train_df.images.loc[ids_train[10]].dtype)
tmp_img[:img_size_ori, :img_size_ori] = train_df.images.loc[ids_train[10]]
fix, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].imshow(tmp_img, cmap="Greys")
axs[0].set_title("Original image")
axs[1].imshow(x_train[10].squeeze(), cmap="Greys")
axs[1].set_title("Scaled image")
# Out:
# Text(0.5,1,'Scaled image')

# %% [markdown]
# # Build Model

# %%
def conv_block_simple(prevlayer, filters, prefix, strides=(1, 1)):
    conv = Conv2D(filters, (3, 3), padding="same", kernel_initializer="he_normal", strides=strides, name=prefix + "_conv")(prevlayer)
    conv = BatchNormalization(name=prefix + "_bn")(conv)
    conv = Activation('relu', name=prefix + "_activation")(conv)
    return conv

def conv_block_simple_no_bn(prevlayer, filters, prefix, strides=(1, 1)):
    conv = Conv2D(filters, (3, 3), padding="same", kernel_initializer="he_normal", strides=strides, name=prefix + "_conv")(prevlayer)
    conv = Activation('relu', name=prefix + "_activation")(conv)
    return conv

# %%
K.clear_session()
def get_unet_resnet(input_shape):
    resnet_base = ResNet50(input_shape=input_shape, include_top=False)

    for l in resnet_base.layers:
        l.trainable = True
    conv1 = resnet_base.get_layer("activation_1").output
    conv2 = resnet_base.get_layer("activation_10").output
    conv3 = resnet_base.get_layer("activation_22").output
    conv4 = resnet_base.get_layer("activation_40").output
    conv5 = resnet_base.get_layer("activation_49").output

    up6 = concatenate([UpSampling2D()(conv5), conv4], axis=-1)
    conv6 = conv_block_simple(up6, 256, "conv6_1")
    conv6 = conv_block_simple(conv6, 256, "conv6_2")

    up7 = concatenate([UpSampling2D()(conv6), conv3], axis=-1)
    conv7 = conv_block_simple(up7, 192, "conv7_1")
    conv7 = conv_block_simple(conv7, 192, "conv7_2")

    up8 = concatenate([UpSampling2D()(conv7), conv2], axis=-1)
    conv8 = conv_block_simple(up8, 128, "conv8_1")
    conv8 = conv_block_simple(conv8, 128, "conv8_2")

    up9 = concatenate([UpSampling2D()(conv8), conv1], axis=-1)
    conv9 = conv_block_simple(up9, 64, "conv9_1")
    conv9 = conv_block_simple(conv9, 64, "conv9_2")

    up10 = UpSampling2D()(conv9)
    conv10 = conv_block_simple(up10, 32, "conv10_1")
    conv10 = conv_block_simple(conv10, 32, "conv10_2")
    conv10 = SpatialDropout2D(0.2)(conv10)
    x = Conv2D(1, (1, 1), activation="sigmoid", name="prediction")(conv10)
    model = Model(resnet_base.input, x)
    return model

# %%
import warnings

from keras.applications.imagenet_utils import _obtain_input_shape
from keras.layers import Input
from keras import layers
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import AveragePooling2D
from keras.layers import GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import BatchNormalization
from keras.models import Model
from keras import backend as K
from keras.engine.topology import get_source_inputs
from keras.utils import layer_utils
from keras.utils.data_utils import get_file

WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'


def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut.
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of middle conv layer at main path
        filters: list of integers, the filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'keras.., current block label, used for generating layer names
    # Returns
        Output tensor for the block.
    """
    filters1, filters2, filters3 = filters
    if K.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv2D(filters1, (1, 1), name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters2, kernel_size,
               padding='same', name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters3, (1, 1), name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = layers.add([x, input_tensor])
    x = Activation('relu')(x)
    return x


def conv_block(input_tensor, kernel_size, filters, stage, block, strides=(2, 2)):
    """A block that has a conv layer at shortcut.
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of middle conv layer at main path
        filters: list of integers, the filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'keras.., current block label, used for generating layer names
    # Returns
        Output tensor for the block.
    Note that from stage 3, the first conv layer at main path is with strides=(2,2)
    And the shortcut should have strides=(2,2) as well
    """
    filters1, filters2, filters3 = filters
    if K.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = Conv2D(filters1, (1, 1), strides=strides,
               name=conv_name_base + '2a')(input_tensor)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters2, kernel_size, padding='same',
               name=conv_name_base + '2b')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters3, (1, 1), name=conv_name_base + '2c')(x)
    x = BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = Conv2D(filters3, (1, 1), strides=strides,
                      name=conv_name_base + '1')(input_tensor)
    shortcut = BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = layers.add([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
def ResNet50(include_top=True, weights='imagenet',
             input_tensor=None, input_shape=None,
             pooling=None,
             classes=1000):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and include_top and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if K.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1

    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', name='conv1')(img_input)
    x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding="same")(x)

    x = conv_block(x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='b')
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='c')

    x = conv_block(x, 3, [128, 128, 512], stage=3, block='a')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='b')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='c')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='d')

    x = conv_block(x, 3, [256, 256, 1024], stage=4, block='a')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='b')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='c')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='d')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='e')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='f')

    x = conv_block(x, 3, [512, 512, 2048], stage=5, block='a')
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b')
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c')

#     x = AveragePooling2D((7, 7), name='avg_pool')(x)

#     if include_top:
#         x = Flatten()(x)
#         x = Dense(classes, activation='softmax', name='fc1000')(x)
#     else:
#         if pooling == 'avg':
#             x = GlobalAveragePooling2D()(x)
#         elif pooling == 'max':
#             x = GlobalMaxPooling2D()(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input
    # Create model.
    model = Model(inputs, x, name='resnet50')

    # load weights
    if weights == 'imagenet':
        if include_top:
            weights_path = get_file('resnet50_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models',
                                    md5_hash='a7b3fe01876f51b976af0dea6bc144eb')
        else:
            weights_path = get_file('resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
                                    WEIGHTS_PATH_NO_TOP,
                                    cache_subdir='models',
                                    md5_hash='a268eb855778b3df3c7506639542a6af')
        model.load_weights(weights_path,by_name=True)
    return model

# %%
def relu6(x):
    return K.relu(x, max_value=6)

# %%
# model = UNet((img_size_target,img_size_target,1),start_ch=16,depth=5,batchnorm=True)
# model = get_unet_mobilenet(input_shape=(128,128,1))
model = get_unet_resnet(input_shape=(img_size_target,img_size_target,3))

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 64, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 64, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 32, 32, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 32, 32, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 32, 32, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 32, 32, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 32, 32, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 32, 32, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 32, 32, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 32, 32, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 32, 32, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 32, 32, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 32, 32, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 32, 32, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 32, 32, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 32, 32, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 32, 32, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 32, 32, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 32, 32, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 32, 32, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 32, 32, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 32, 32, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 16, 16, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 16, 16, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 16, 16, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 16, 16, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 16, 16, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 16, 16, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 16, 16, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 16, 16, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 16, 16, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 16, 16, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 16, 16, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 16, 16, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 16, 16, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 16, 16, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 16, 16, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 16, 16, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 16, 16, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 16, 16, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 16, 16, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 16, 16, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 16, 16, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 16, 16, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 16, 16, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 16, 16, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 16, 16, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 16, 16, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 8, 8, 256)    131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 8, 8, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 8, 8, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 8, 8, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 8, 8, 1024)   263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 8, 8, 1024)   525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 8, 8, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 8, 8, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 1024)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 8, 8, 256)    262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 8, 8, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 8, 8, 256)    590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 8, 8, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 8, 8, 1024)   263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 8, 8, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 1024)   0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 1024)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 8, 8, 256)    262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 8, 8, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 8, 8, 256)    590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 8, 8, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 8, 8, 1024)   263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 8, 8, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 1024)   0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 1024)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 8, 8, 256)    262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 8, 8, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 8, 8, 256)    590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 8, 8, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 8, 8, 1024)   263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 8, 8, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 1024)   0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 1024)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 8, 8, 256)    262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 8, 8, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 8, 8, 256)    590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 8, 8, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 8, 8, 1024)   263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 8, 8, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 1024)   0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 1024)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 8, 8, 256)    262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 8, 8, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 8, 8, 256)    590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 8, 8, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 8, 8, 1024)   263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 8, 8, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 1024)   0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 1024)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 4, 4, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 4, 4, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 4, 4, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 4, 4, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 4, 4, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 4, 4, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 4, 4, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 4, 4, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 4, 4, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 4, 4, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 4, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 4, 4, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 4, 4, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 4, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 4, 4, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 4, 4, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 4, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 4, 4, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 4, 4, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 4, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 4, 4, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 4, 4, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 4, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 4, 4, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 4, 4, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 4, 4, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 4, 4, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, 4, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 4, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 3072)   0           up_sampling2d_1[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv6_1_conv (Conv2D)           (None, 8, 8, 256)    7078144     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv6_1_bn (BatchNormalization) (None, 8, 8, 256)    1024        conv6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv6_1_activation (Activation) (None, 8, 8, 256)    0           conv6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv6_2_conv (Conv2D)           (None, 8, 8, 256)    590080      conv6_1_activation[0][0]
# __________________________________________________________________________________________________
# conv6_2_bn (BatchNormalization) (None, 8, 8, 256)    1024        conv6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv6_2_activation (Activation) (None, 8, 8, 256)    0           conv6_2_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 256)  0           conv6_2_activation[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 768)  0           up_sampling2d_2[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# conv7_1_conv (Conv2D)           (None, 16, 16, 192)  1327296     concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv7_1_bn (BatchNormalization) (None, 16, 16, 192)  768         conv7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv7_1_activation (Activation) (None, 16, 16, 192)  0           conv7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv7_2_conv (Conv2D)           (None, 16, 16, 192)  331968      conv7_1_activation[0][0]
# __________________________________________________________________________________________________
# conv7_2_bn (BatchNormalization) (None, 16, 16, 192)  768         conv7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv7_2_activation (Activation) (None, 16, 16, 192)  0           conv7_2_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 192)  0           conv7_2_activation[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 448)  0           up_sampling2d_3[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# conv8_1_conv (Conv2D)           (None, 32, 32, 128)  516224      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv8_1_bn (BatchNormalization) (None, 32, 32, 128)  512         conv8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv8_1_activation (Activation) (None, 32, 32, 128)  0           conv8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv8_2_conv (Conv2D)           (None, 32, 32, 128)  147584      conv8_1_activation[0][0]
# __________________________________________________________________________________________________
# conv8_2_bn (BatchNormalization) (None, 32, 32, 128)  512         conv8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv8_2_activation (Activation) (None, 32, 32, 128)  0           conv8_2_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 128)  0           conv8_2_activation[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 192)  0           up_sampling2d_4[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv9_1_conv (Conv2D)           (None, 64, 64, 64)   110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv9_1_bn (BatchNormalization) (None, 64, 64, 64)   256         conv9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv9_1_activation (Activation) (None, 64, 64, 64)   0           conv9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv9_2_conv (Conv2D)           (None, 64, 64, 64)   36928       conv9_1_activation[0][0]
# __________________________________________________________________________________________________
# conv9_2_bn (BatchNormalization) (None, 64, 64, 64)   256         conv9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv9_2_activation (Activation) (None, 64, 64, 64)   0           conv9_2_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 64) 0           conv9_2_activation[0][0]
# __________________________________________________________________________________________________
# conv10_1_conv (Conv2D)          (None, 128, 128, 32) 18464       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv10_1_bn (BatchNormalization (None, 128, 128, 32) 128         conv10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv10_1_activation (Activation (None, 128, 128, 32) 0           conv10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv10_2_conv (Conv2D)          (None, 128, 128, 32) 9248        conv10_1_activation[0][0]
# __________________________________________________________________________________________________
# conv10_2_bn (BatchNormalization (None, 128, 128, 32) 128         conv10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv10_2_activation (Activation (None, 128, 128, 32) 0           conv10_2_bn[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 128, 128, 32) 0           conv10_2_activation[0][0]
# __________________________________________________________________________________________________
# prediction (Conv2D)             (None, 128, 128, 1)  33          spatial_dropout2d_1[0][0]
# ==================================================================================================
# Total params: 33,759,713
# Trainable params: 33,703,905
# Non-trainable params: 55,808
# __________________________________________________________________________________________________

# %% [markdown]
# # Define Loss Function

# %%
from keras.losses import binary_crossentropy
from keras import backend as K

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def bce_logdice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

def weighted_bce_loss(y_true, y_pred, weight):
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = weight * (logit_y_pred * (1. - y_true) + 
                     K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    loss = 1. - K.sum(score)
    return loss

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd
    averaged_mask = K.pool2d(
            y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
    return loss

def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0        
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %% [markdown]
# # Define Model

# %%
import gc
gc.enable()

# %%
model.compile(loss=lovasz_loss, optimizer="adam", metrics=["accuracy", my_iou_metric_2])

# %%
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)

# %%
fig, axs = plt.subplots(2, 10, figsize=(15,3))
for i in range(10):
    axs[0][i].imshow(x_train[i].squeeze(), cmap="Greys")
    axs[0][i].imshow(y_train[i].squeeze(), cmap="Greens", alpha=0.3)
    axs[1][i].imshow(x_train[int(len(x_train)/2 + i)].squeeze(), cmap="Greys")
    axs[1][i].imshow(y_train[int(len(y_train)/2 + i)].squeeze(), cmap="Greens", alpha=0.3)
fig.suptitle("Top row: original images, bottom row: augmented images")
# Out:
# Text(0.5,0.98,'Top row: original images, bottom row: augmented images')

# %%
x_train = np.repeat(x_train,3,axis=3)
x_valid = np.repeat(x_valid,3,axis=3)

# %% [markdown]
# # Training

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, monitor='val_my_iou_metric_2', mode = 'max', verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 200
batch_size = 64

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[model_checkpoint, reduce_lr],
                    shuffle=True,
                    verbose=2)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
#  - 85s - loss: 0.5619 - acc: 0.8896 - my_iou_metric: 0.5269 - val_loss: 1.4475 - val_acc: 0.7372 - val_my_iou_metric: 0.3180
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.31800, saving model to ./keras.model
# Epoch 2/200
#  - 64s - loss: 0.4063 - acc: 0.9193 - my_iou_metric: 0.6485 - val_loss: 2.7411 - val_acc: 0.6334 - val_my_iou_metric: 0.2494
#
# Epoch 00002: val_my_iou_metric did not improve from 0.31800
# Epoch 3/200
#  - 65s - loss: 0.3725 - acc: 0.9234 - my_iou_metric: 0.6623 - val_loss: 1.7586 - val_acc: 0.8155 - val_my_iou_metric: 0.3404
#
# Epoch 00003: val_my_iou_metric improved from 0.31800 to 0.34038, saving model to ./keras.model
# Epoch 4/200
#  - 65s - loss: 0.3401 - acc: 0.9289 - my_iou_metric: 0.6863 - val_loss: 1.0177 - val_acc: 0.8418 - val_my_iou_metric: 0.4506
#
# Epoch 00004: val_my_iou_metric improved from 0.34038 to 0.45062, saving model to ./keras.model
# Epoch 5/200
#  - 65s - loss: 0.3182 - acc: 0.9326 - my_iou_metric: 0.7011 - val_loss: 1.0698 - val_acc: 0.8131 - val_my_iou_metric: 0.4841
#
# Epoch 00005: val_my_iou_metric improved from 0.45062 to 0.48412, saving model to ./keras.model
# Epoch 6/200
#  - 65s - loss: 0.2877 - acc: 0.9383 - my_iou_metric: 0.7280 - val_loss: 0.5601 - val_acc: 0.8941 - val_my_iou_metric: 0.6256
#
# Epoch 00006: val_my_iou_metric improved from 0.48412 to 0.62563, saving model to ./keras.model
# Epoch 7/200
#  - 65s - loss: 0.2706 - acc: 0.9410 - my_iou_metric: 0.7308 - val_loss: 0.4957 - val_acc: 0.9122 - val_my_iou_metric: 0.6775
#
# Epoch 00007: val_my_iou_metric improved from 0.62563 to 0.67750, saving model to ./keras.model
# Epoch 8/200
#  - 65s - loss: 0.2524 - acc: 0.9440 - my_iou_metric: 0.7423 - val_loss: 1.1619 - val_acc: 0.8545 - val_my_iou_metric: 0.4620
#
# Epoch 00008: val_my_iou_metric did not improve from 0.67750
# Epoch 9/200
#  - 65s - loss: 0.2508 - acc: 0.9451 - my_iou_metric: 0.7355 - val_loss: 2.3091 - val_acc: 0.7698 - val_my_iou_metric: 0.2105
#
# Epoch 00009: val_my_iou_metric did not improve from 0.67750
# Epoch 10/200
#  - 65s - loss: 0.2639 - acc: 0.9428 - my_iou_metric: 0.7321 - val_loss: 0.4117 - val_acc: 0.9212 - val_my_iou_metric: 0.6827
#
# Epoch 00010: val_my_iou_metric improved from 0.67750 to 0.68275, saving model to ./keras.model
# Epoch 11/200
#  - 65s - loss: 0.2335 - acc: 0.9469 - my_iou_metric: 0.7413 - val_loss: 2.1280 - val_acc: 0.7657 - val_my_iou_metric: 0.4086
#
# Epoch 00011: val_my_iou_metric did not improve from 0.68275
# Epoch 12/200
#  - 65s - loss: 0.2326 - acc: 0.9478 - my_iou_metric: 0.7368 - val_loss: 1.5297 - val_acc: 0.8151 - val_my_iou_metric: 0.4749
#
# Epoch 00012: val_my_iou_metric did not improve from 0.68275
# Epoch 13/200
#  - 65s - loss: 0.1979 - acc: 0.9540 - my_iou_metric: 0.7651 - val_loss: 1.0161 - val_acc: 0.8512 - val_my_iou_metric: 0.5300
#
# Epoch 00013: val_my_iou_metric did not improve from 0.68275
# Epoch 14/200
#  - 65s - loss: 0.1970 - acc: 0.9540 - my_iou_metric: 0.7619 - val_loss: 0.8762 - val_acc: 0.8467 - val_my_iou_metric: 0.5366
#
# Epoch 00014: val_my_iou_metric did not improve from 0.68275
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/200
#  - 65s - loss: 0.1458 - acc: 0.9637 - my_iou_metric: 0.7995 - val_loss: 0.3257 - val_acc: 0.9360 - val_my_iou_metric: 0.7712
#
# Epoch 00015: val_my_iou_metric improved from 0.68275 to 0.77125, saving model to ./keras.model
# Epoch 16/200
#  - 65s - loss: 0.1221 - acc: 0.9678 - my_iou_metric: 0.8140 - val_loss: 0.3081 - val_acc: 0.9388 - val_my_iou_metric: 0.7780
#
# Epoch 00016: val_my_iou_metric improved from 0.77125 to 0.77800, saving model to ./keras.model
# Epoch 17/200
#  - 64s - loss: 0.1210 - acc: 0.9681 - my_iou_metric: 0.8165 - val_loss: 0.3013 - val_acc: 0.9388 - val_my_iou_metric: 0.7794
#
# Epoch 00017: val_my_iou_metric improved from 0.77800 to 0.77937, saving model to ./keras.model
# Epoch 18/200
#  - 64s - loss: 0.1130 - acc: 0.9694 - my_iou_metric: 0.8212 - val_loss: 0.3256 - val_acc: 0.9377 - val_my_iou_metric: 0.7731
#
# Epoch 00018: val_my_iou_metric did not improve from 0.77937
# Epoch 19/200
#  - 64s - loss: 0.1073 - acc: 0.9704 - my_iou_metric: 0.8302 - val_loss: 0.3165 - val_acc: 0.9386 - val_my_iou_metric: 0.7781
#
# Epoch 00019: val_my_iou_metric did not improve from 0.77937
# Epoch 20/200
#  - 64s - loss: 0.1039 - acc: 0.9709 - my_iou_metric: 0.8298 - val_loss: 0.3173 - val_acc: 0.9388 - val_my_iou_metric: 0.7825
#
# Epoch 00020: val_my_iou_metric improved from 0.77937 to 0.78250, saving model to ./keras.model
# Epoch 21/200
#  - 64s - loss: 0.1003 - acc: 0.9714 - my_iou_metric: 0.8344 - val_loss: 0.3266 - val_acc: 0.9408 - val_my_iou_metric: 0.7759
#
# Epoch 00021: val_my_iou_metric did not improve from 0.78250
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 22/200
#  - 64s - loss: 0.0994 - acc: 0.9717 - my_iou_metric: 0.8312 - val_loss: 0.3225 - val_acc: 0.9400 - val_my_iou_metric: 0.7759
#
# Epoch 00022: val_my_iou_metric did not improve from 0.78250
# Epoch 23/200
#  - 64s - loss: 0.0987 - acc: 0.9719 - my_iou_metric: 0.8344 - val_loss: 0.3230 - val_acc: 0.9396 - val_my_iou_metric: 0.7753
#
# Epoch 00023: val_my_iou_metric did not improve from 0.78250
# Epoch 24/200
#  - 64s - loss: 0.0965 - acc: 0.9723 - my_iou_metric: 0.8356 - val_loss: 0.3234 - val_acc: 0.9394 - val_my_iou_metric: 0.7739
#
# Epoch 00024: val_my_iou_metric did not improve from 0.78250
# Epoch 25/200
#  - 65s - loss: 0.0958 - acc: 0.9724 - my_iou_metric: 0.8360 - val_loss: 0.3243 - val_acc: 0.9397 - val_my_iou_metric: 0.7753
#
# Epoch 00025: val_my_iou_metric did not improve from 0.78250
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 26/200
#  - 65s - loss: 0.0963 - acc: 0.9721 - my_iou_metric: 0.8349 - val_loss: 0.3234 - val_acc: 0.9395 - val_my_iou_metric: 0.7736
#
# Epoch 00026: val_my_iou_metric did not improve from 0.78250
# Epoch 27/200
#  - 65s - loss: 0.0959 - acc: 0.9722 - my_iou_metric: 0.8365 - val_loss: 0.3240 - val_acc: 0.9397 - val_my_iou_metric: 0.7757
#
# Epoch 00027: val_my_iou_metric did not improve from 0.78250
# Epoch 28/200
#  - 65s - loss: 0.0975 - acc: 0.9721 - my_iou_metric: 0.8367 - val_loss: 0.3228 - val_acc: 0.9397 - val_my_iou_metric: 0.7757
#
# Epoch 00028: val_my_iou_metric did not improve from 0.78250
# Epoch 29/200
#  - 65s - loss: 0.0960 - acc: 0.9723 - my_iou_metric: 0.8357 - val_loss: 0.3206 - val_acc: 0.9396 - val_my_iou_metric: 0.7765
#
# Epoch 00029: val_my_iou_metric did not improve from 0.78250
# Epoch 30/200
#  - 65s - loss: 0.0937 - acc: 0.9727 - my_iou_metric: 0.8374 - val_loss: 0.3213 - val_acc: 0.9396 - val_my_iou_metric: 0.7764
#
# Epoch 00030: val_my_iou_metric did not improve from 0.78250
# Epoch 31/200
#  - 65s - loss: 0.0929 - acc: 0.9728 - my_iou_metric: 0.8391 - val_loss: 0.3204 - val_acc: 0.9397 - val_my_iou_metric: 0.7774
#
# Epoch 00031: val_my_iou_metric did not improve from 0.78250
# Epoch 32/200
#  - 65s - loss: 0.0940 - acc: 0.9726 - my_iou_metric: 0.8356 - val_loss: 0.3225 - val_acc: 0.9395 - val_my_iou_metric: 0.7741
#
# Epoch 00032: val_my_iou_metric did not improve from 0.78250
# Epoch 33/200
#  - 65s - loss: 0.0942 - acc: 0.9727 - my_iou_metric: 0.8358 - val_loss: 0.3223 - val_acc: 0.9396 - val_my_iou_metric: 0.7745
#
# Epoch 00033: val_my_iou_metric did not improve from 0.78250
# Epoch 34/200
#  - 65s - loss: 0.0923 - acc: 0.9730 - my_iou_metric: 0.8410 - val_loss: 0.3249 - val_acc: 0.9397 - val_my_iou_metric: 0.7740
#
# Epoch 00034: val_my_iou_metric did not improve from 0.78250
# Epoch 35/200
#  - 65s - loss: 0.0935 - acc: 0.9727 - my_iou_metric: 0.8375 - val_loss: 0.3227 - val_acc: 0.9399 - val_my_iou_metric: 0.7764
#
# Epoch 00035: val_my_iou_metric did not improve from 0.78250
# Epoch 36/200
#  - 65s - loss: 0.0927 - acc: 0.9728 - my_iou_metric: 0.8381 - val_loss: 0.3227 - val_acc: 0.9402 - val_my_iou_metric: 0.7736
#
# Epoch 00036: val_my_iou_metric did not improve from 0.78250
# Epoch 37/200
#  - 65s - loss: 0.0923 - acc: 0.9729 - my_iou_metric: 0.8386 - val_loss: 0.3204 - val_acc: 0.9403 - val_my_iou_metric: 0.7723
#
# Epoch 00037: val_my_iou_metric did not improve from 0.78250
# Epoch 38/200
#  - 65s - loss: 0.0923 - acc: 0.9730 - my_iou_metric: 0.8394 - val_loss: 0.3187 - val_acc: 0.9404 - val_my_iou_metric: 0.7758
#
# Epoch 00038: val_my_iou_metric did not improve from 0.78250
# Epoch 39/200
#  - 65s - loss: 0.0904 - acc: 0.9733 - my_iou_metric: 0.8392 - val_loss: 0.3210 - val_acc: 0.9399 - val_my_iou_metric: 0.7746
#
# Epoch 00039: val_my_iou_metric did not improve from 0.78250
# Epoch 40/200
#  - 65s - loss: 0.0951 - acc: 0.9725 - my_iou_metric: 0.8342 - val_loss: 0.3215 - val_acc: 0.9405 - val_my_iou_metric: 0.7761
#
# Epoch 00040: val_my_iou_metric did not improve from 0.78250
# Epoch 41/200
#  - 65s - loss: 0.0908 - acc: 0.9731 - my_iou_metric: 0.8388 - val_loss: 0.3196 - val_acc: 0.9406 - val_my_iou_metric: 0.7754
#
# Epoch 00041: val_my_iou_metric did not improve from 0.78250
# Epoch 42/200
#  - 65s - loss: 0.0910 - acc: 0.9732 - my_iou_metric: 0.8401 - val_loss: 0.3236 - val_acc: 0.9406 - val_my_iou_metric: 0.7710
#
# Epoch 00042: val_my_iou_metric did not improve from 0.78250
# Epoch 43/200
#  - 65s - loss: 0.0895 - acc: 0.9735 - my_iou_metric: 0.8407 - val_loss: 0.3195 - val_acc: 0.9407 - val_my_iou_metric: 0.7764
#
# Epoch 00043: val_my_iou_metric did not improve from 0.78250
# Epoch 44/200
#  - 65s - loss: 0.0890 - acc: 0.9735 - my_iou_metric: 0.8419 - val_loss: 0.3224 - val_acc: 0.9405 - val_my_iou_metric: 0.7748
#
# Epoch 00044: val_my_iou_metric did not improve from 0.78250
# Epoch 45/200
#  - 65s - loss: 0.0898 - acc: 0.9734 - my_iou_metric: 0.8390 - val_loss: 0.3188 - val_acc: 0.9405 - val_my_iou_metric: 0.7729
#
# Epoch 00045: val_my_iou_metric did not improve from 0.78250
# Epoch 46/200
#  - 65s - loss: 0.0893 - acc: 0.9734 - my_iou_metric: 0.8400 - val_loss: 0.3195 - val_acc: 0.9405 - val_my_iou_metric: 0.7725
#
# Epoch 00046: val_my_iou_metric did not improve from 0.78250
# Epoch 47/200
#  - 65s - loss: 0.0881 - acc: 0.9736 - my_iou_metric: 0.8423 - val_loss: 0.3187 - val_acc: 0.9408 - val_my_iou_metric: 0.7754
#
# Epoch 00047: val_my_iou_metric did not improve from 0.78250
# Epoch 48/200
#  - 65s - loss: 0.0881 - acc: 0.9736 - my_iou_metric: 0.8407 - val_loss: 0.3215 - val_acc: 0.9407 - val_my_iou_metric: 0.7719
#
# Epoch 00048: val_my_iou_metric did not improve from 0.78250
# Epoch 49/200
#  - 65s - loss: 0.0901 - acc: 0.9732 - my_iou_metric: 0.8401 - val_loss: 0.3199 - val_acc: 0.9408 - val_my_iou_metric: 0.7729
#
# Epoch 00049: val_my_iou_metric did not improve from 0.78250
# Epoch 50/200
#  - 65s - loss: 0.0860 - acc: 0.9740 - my_iou_metric: 0.8443 - val_loss: 0.3212 - val_acc: 0.9409 - val_my_iou_metric: 0.7749
#
# Epoch 00050: val_my_iou_metric did not improve from 0.78250
# Epoch 51/200
#  - 65s - loss: 0.0860 - acc: 0.9741 - my_iou_metric: 0.8411 - val_loss: 0.3245 - val_acc: 0.9411 - val_my_iou_metric: 0.7719
#
# Epoch 00051: val_my_iou_metric did not improve from 0.78250
# Epoch 52/200
#  - 65s - loss: 0.0851 - acc: 0.9741 - my_iou_metric: 0.8452 - val_loss: 0.3251 - val_acc: 0.9409 - val_my_iou_metric: 0.7705
#
# Epoch 00052: val_my_iou_metric did not improve from 0.78250
# Epoch 53/200
#  - 65s - loss: 0.0844 - acc: 0.9742 - my_iou_metric: 0.8433 - val_loss: 0.3265 - val_acc: 0.9411 - val_my_iou_metric: 0.7702
#
# Epoch 00053: val_my_iou_metric did not improve from 0.78250
# Epoch 54/200
#  - 65s - loss: 0.0853 - acc: 0.9741 - my_iou_metric: 0.8453 - val_loss: 0.3241 - val_acc: 0.9409 - val_my_iou_metric: 0.7740
#
# Epoch 00054: val_my_iou_metric did not improve from 0.78250
# Epoch 55/200
#  - 65s - loss: 0.0859 - acc: 0.9741 - my_iou_metric: 0.8420 - val_loss: 0.3224 - val_acc: 0.9411 - val_my_iou_metric: 0.7766
#
# Epoch 00055: val_my_iou_metric did not improve from 0.78250
# Epoch 56/200
#  - 65s - loss: 0.0833 - acc: 0.9745 - my_iou_metric: 0.8455 - val_loss: 0.3262 - val_acc: 0.9410 - val_my_iou_metric: 0.7732
#
# Epoch 00056: val_my_iou_metric did not improve from 0.78250
# Epoch 57/200
#  - 65s - loss: 0.0844 - acc: 0.9743 - my_iou_metric: 0.8439 - val_loss: 0.3258 - val_acc: 0.9410 - val_my_iou_metric: 0.7732
#
# Epoch 00057: val_my_iou_metric did not improve from 0.78250
# Epoch 58/200
#  - 65s - loss: 0.0830 - acc: 0.9744 - my_iou_metric: 0.8467 - val_loss: 0.3271 - val_acc: 0.9409 - val_my_iou_metric: 0.7761
#
# Epoch 00058: val_my_iou_metric did not improve from 0.78250
# Epoch 59/200
#  - 65s - loss: 0.0830 - acc: 0.9744 - my_iou_metric: 0.8467 - val_loss: 0.3274 - val_acc: 0.9412 - val_my_iou_metric: 0.7705
#
# Epoch 00059: val_my_iou_metric did not improve from 0.78250
# Epoch 60/200
#  - 65s - loss: 0.0816 - acc: 0.9747 - my_iou_metric: 0.8452 - val_loss: 0.3279 - val_acc: 0.9412 - val_my_iou_metric: 0.7730
#
# Epoch 00060: val_my_iou_metric did not improve from 0.78250
# Epoch 61/200
#  - 65s - loss: 0.0817 - acc: 0.9746 - my_iou_metric: 0.8459 - val_loss: 0.3278 - val_acc: 0.9410 - val_my_iou_metric: 0.7681
#
# Epoch 00061: val_my_iou_metric did not improve from 0.78250
# Epoch 62/200
#  - 65s - loss: 0.0807 - acc: 0.9749 - my_iou_metric: 0.8466 - val_loss: 0.3298 - val_acc: 0.9412 - val_my_iou_metric: 0.7738
#
# Epoch 00062: val_my_iou_metric did not improve from 0.78250
# Epoch 63/200
#  - 65s - loss: 0.0821 - acc: 0.9747 - my_iou_metric: 0.8457 - val_loss: 0.3265 - val_acc: 0.9414 - val_my_iou_metric: 0.7782
#
# Epoch 00063: val_my_iou_metric did not improve from 0.78250
# Epoch 64/200
#  - 65s - loss: 0.0800 - acc: 0.9750 - my_iou_metric: 0.8479 - val_loss: 0.3282 - val_acc: 0.9413 - val_my_iou_metric: 0.7728
#
# Epoch 00064: val_my_iou_metric did not improve from 0.78250
# Epoch 65/200
#  - 65s - loss: 0.0802 - acc: 0.9750 - my_iou_metric: 0.8492 - val_loss: 0.3290 - val_acc: 0.9413 - val_my_iou_metric: 0.7708
#
# Epoch 00065: val_my_iou_metric did not improve from 0.78250
# Epoch 66/200
#  - 65s - loss: 0.0800 - acc: 0.9750 - my_iou_metric: 0.8496 - val_loss: 0.3309 - val_acc: 0.9411 - val_my_iou_metric: 0.7712
#
# Epoch 00066: val_my_iou_metric did not improve from 0.78250
# Epoch 67/200
#  - 65s - loss: 0.0807 - acc: 0.9749 - my_iou_metric: 0.8466 - val_loss: 0.3295 - val_acc: 0.9409 - val_my_iou_metric: 0.7740
#
# Epoch 00067: val_my_iou_metric did not improve from 0.78250
# Epoch 68/200
#  - 65s - loss: 0.0782 - acc: 0.9753 - my_iou_metric: 0.8508 - val_loss: 0.3311 - val_acc: 0.9410 - val_my_iou_metric: 0.7718
#
# Epoch 00068: val_my_iou_metric did not improve from 0.78250
# Epoch 69/200
#  - 65s - loss: 0.0789 - acc: 0.9753 - my_iou_metric: 0.8487 - val_loss: 0.3289 - val_acc: 0.9411 - val_my_iou_metric: 0.7709
#
# Epoch 00069: val_my_iou_metric did not improve from 0.78250
# Epoch 70/200
#  - 65s - loss: 0.0793 - acc: 0.9751 - my_iou_metric: 0.8492 - val_loss: 0.3283 - val_acc: 0.9416 - val_my_iou_metric: 0.7720
#
# Epoch 00070: val_my_iou_metric did not improve from 0.78250
# Epoch 71/200
#  - 65s - loss: 0.0782 - acc: 0.9754 - my_iou_metric: 0.8498 - val_loss: 0.3230 - val_acc: 0.9422 - val_my_iou_metric: 0.7760
#
# Epoch 00071: val_my_iou_metric did not improve from 0.78250
# Epoch 72/200
#  - 65s - loss: 0.0772 - acc: 0.9754 - my_iou_metric: 0.8523 - val_loss: 0.3285 - val_acc: 0.9420 - val_my_iou_metric: 0.7715
#
# Epoch 00072: val_my_iou_metric did not improve from 0.78250
# Epoch 73/200
#  - 65s - loss: 0.0775 - acc: 0.9755 - my_iou_metric: 0.8512 - val_loss: 0.3293 - val_acc: 0.9424 - val_my_iou_metric: 0.7723
#
# Epoch 00073: val_my_iou_metric did not improve from 0.78250
# Epoch 74/200
#  - 65s - loss: 0.0782 - acc: 0.9753 - my_iou_metric: 0.8502 - val_loss: 0.3332 - val_acc: 0.9421 - val_my_iou_metric: 0.7669
#
# Epoch 00074: val_my_iou_metric did not improve from 0.78250
# Epoch 75/200
#  - 65s - loss: 0.0746 - acc: 0.9760 - my_iou_metric: 0.8544 - val_loss: 0.3301 - val_acc: 0.9420 - val_my_iou_metric: 0.7688
#
# Epoch 00075: val_my_iou_metric did not improve from 0.78250
# Epoch 76/200
#  - 65s - loss: 0.0753 - acc: 0.9758 - my_iou_metric: 0.8536 - val_loss: 0.3325 - val_acc: 0.9424 - val_my_iou_metric: 0.7744
#
# Epoch 00076: val_my_iou_metric did not improve from 0.78250
# Epoch 77/200
#  - 65s - loss: 0.0750 - acc: 0.9759 - my_iou_metric: 0.8538 - val_loss: 0.3298 - val_acc: 0.9420 - val_my_iou_metric: 0.7673
#
# Epoch 00077: val_my_iou_metric did not improve from 0.78250
# Epoch 78/200
#  - 65s - loss: 0.0755 - acc: 0.9758 - my_iou_metric: 0.8514 - val_loss: 0.3308 - val_acc: 0.9420 - val_my_iou_metric: 0.7685
#
# Epoch 00078: val_my_iou_metric did not improve from 0.78250
# Epoch 79/200
#  - 65s - loss: 0.0755 - acc: 0.9758 - my_iou_metric: 0.8547 - val_loss: 0.3342 - val_acc: 0.9422 - val_my_iou_metric: 0.7669
# Epoch 00079: val_my_iou_metric did not improve from 0.78250
# Epoch 80/200
#  - 65s - loss: 0.0748 - acc: 0.9759 - my_iou_metric: 0.8533 - val_loss: 0.3308 - val_acc: 0.9425 - val_my_iou_metric: 0.7704
#
# Epoch 00080: val_my_iou_metric did not improve from 0.78250
# Epoch 81/200
#  - 65s - loss: 0.0756 - acc: 0.9759 - my_iou_metric: 0.8508 - val_loss: 0.3282 - val_acc: 0.9422 - val_my_iou_metric: 0.7662
#
# Epoch 00081: val_my_iou_metric did not improve from 0.78250
# Epoch 82/200
#  - 65s - loss: 0.0734 - acc: 0.9762 - my_iou_metric: 0.8545 - val_loss: 0.3351 - val_acc: 0.9422 - val_my_iou_metric: 0.7744
#
# Epoch 00082: val_my_iou_metric did not improve from 0.78250
# Epoch 83/200
#  - 65s - loss: 0.0736 - acc: 0.9761 - my_iou_metric: 0.8528 - val_loss: 0.3371 - val_acc: 0.9422 - val_my_iou_metric: 0.7699
#
# Epoch 00083: val_my_iou_metric did not improve from 0.78250
# Epoch 84/200
#  - 65s - loss: 0.0722 - acc: 0.9764 - my_iou_metric: 0.8555 - val_loss: 0.3369 - val_acc: 0.9417 - val_my_iou_metric: 0.7690
#
# Epoch 00084: val_my_iou_metric did not improve from 0.78250
# Epoch 85/200
#  - 65s - loss: 0.0725 - acc: 0.9764 - my_iou_metric: 0.8570 - val_loss: 0.3372 - val_acc: 0.9424 - val_my_iou_metric: 0.7701
#
# Epoch 00085: val_my_iou_metric did not improve from 0.78250
# Epoch 86/200
#  - 65s - loss: 0.0719 - acc: 0.9764 - my_iou_metric: 0.8564 - val_loss: 0.3340 - val_acc: 0.9423 - val_my_iou_metric: 0.7749
#
# Epoch 00086: val_my_iou_metric did not improve from 0.78250
# Epoch 87/200
#  - 65s - loss: 0.0719 - acc: 0.9764 - my_iou_metric: 0.8572 - val_loss: 0.3340 - val_acc: 0.9424 - val_my_iou_metric: 0.7696
#
# Epoch 00087: val_my_iou_metric did not improve from 0.78250
# Epoch 88/200
#  - 65s - loss: 0.0713 - acc: 0.9765 - my_iou_metric: 0.8540 - val_loss: 0.3391 - val_acc: 0.9419 - val_my_iou_metric: 0.7719
#
# Epoch 00088: val_my_iou_metric did not improve from 0.78250
# Epoch 89/200
#  - 65s - loss: 0.0707 - acc: 0.9766 - my_iou_metric: 0.8575 - val_loss: 0.3384 - val_acc: 0.9419 - val_my_iou_metric: 0.7700
#
# Epoch 00089: val_my_iou_metric did not improve from 0.78250
# Epoch 90/200
#  - 65s - loss: 0.0705 - acc: 0.9767 - my_iou_metric: 0.8589 - val_loss: 0.3365 - val_acc: 0.9425 - val_my_iou_metric: 0.7671
#
# Epoch 00090: val_my_iou_metric did not improve from 0.78250
# Epoch 91/200
#  - 65s - loss: 0.0699 - acc: 0.9767 - my_iou_metric: 0.8596 - val_loss: 0.3401 - val_acc: 0.9419 - val_my_iou_metric: 0.7689
#
# Epoch 00091: val_my_iou_metric did not improve from 0.78250
# Epoch 92/200
#  - 65s - loss: 0.0700 - acc: 0.9767 - my_iou_metric: 0.8560 - val_loss: 0.3391 - val_acc: 0.9425 - val_my_iou_metric: 0.7721
#
# Epoch 00092: val_my_iou_metric did not improve from 0.78250
# Epoch 93/200
#  - 65s - loss: 0.0697 - acc: 0.9767 - my_iou_metric: 0.8574 - val_loss: 0.3393 - val_acc: 0.9426 - val_my_iou_metric: 0.7697
#
# Epoch 00093: val_my_iou_metric did not improve from 0.78250
# Epoch 94/200
#  - 65s - loss: 0.0689 - acc: 0.9769 - my_iou_metric: 0.8599 - val_loss: 0.3430 - val_acc: 0.9422 - val_my_iou_metric: 0.7734
#
# Epoch 00094: val_my_iou_metric did not improve from 0.78250
# Epoch 95/200
#  - 65s - loss: 0.0691 - acc: 0.9769 - my_iou_metric: 0.8603 - val_loss: 0.3435 - val_acc: 0.9419 - val_my_iou_metric: 0.7711
#
# Epoch 00095: val_my_iou_metric did not improve from 0.78250
# Epoch 96/200
#  - 65s - loss: 0.0699 - acc: 0.9767 - my_iou_metric: 0.8581 - val_loss: 0.3452 - val_acc: 0.9419 - val_my_iou_metric: 0.7723
#
# Epoch 00096: val_my_iou_metric did not improve from 0.78250
# Epoch 97/200
#  - 65s - loss: 0.0688 - acc: 0.9769 - my_iou_metric: 0.8597 - val_loss: 0.3441 - val_acc: 0.9417 - val_my_iou_metric: 0.7734
#
# Epoch 00097: val_my_iou_metric did not improve from 0.78250
# Epoch 98/200
#  - 65s - loss: 0.0688 - acc: 0.9770 - my_iou_metric: 0.8586 - val_loss: 0.3421 - val_acc: 0.9421 - val_my_iou_metric: 0.7690
#
# Epoch 00098: val_my_iou_metric did not improve from 0.78250
# Epoch 99/200
#  - 65s - loss: 0.0672 - acc: 0.9772 - my_iou_metric: 0.8580 - val_loss: 0.3451 - val_acc: 0.9421 - val_my_iou_metric: 0.7706
#
# Epoch 00099: val_my_iou_metric did not improve from 0.78250
# Epoch 100/200
#  - 65s - loss: 0.0677 - acc: 0.9771 - my_iou_metric: 0.8593 - val_loss: 0.3441 - val_acc: 0.9422 - val_my_iou_metric: 0.7697
#
# Epoch 00100: val_my_iou_metric did not improve from 0.78250
# Epoch 101/200
#  - 65s - loss: 0.0666 - acc: 0.9773 - my_iou_metric: 0.8603 - val_loss: 0.3410 - val_acc: 0.9425 - val_my_iou_metric: 0.7684
#
# Epoch 00101: val_my_iou_metric did not improve from 0.78250
# Epoch 102/200
#  - 65s - loss: 0.0665 - acc: 0.9773 - my_iou_metric: 0.8601 - val_loss: 0.3437 - val_acc: 0.9424 - val_my_iou_metric: 0.7661
#
# Epoch 00102: val_my_iou_metric did not improve from 0.78250
# Epoch 103/200
#  - 65s - loss: 0.0665 - acc: 0.9774 - my_iou_metric: 0.8618 - val_loss: 0.3488 - val_acc: 0.9418 - val_my_iou_metric: 0.7662
#
# Epoch 00103: val_my_iou_metric did not improve from 0.78250
# Epoch 104/200
#  - 65s - loss: 0.0660 - acc: 0.9775 - my_iou_metric: 0.8624 - val_loss: 0.3456 - val_acc: 0.9422 - val_my_iou_metric: 0.7686
#
# Epoch 00104: val_my_iou_metric did not improve from 0.78250
# Epoch 105/200
#  - 65s - loss: 0.0673 - acc: 0.9772 - my_iou_metric: 0.8606 - val_loss: 0.3461 - val_acc: 0.9419 - val_my_iou_metric: 0.7599
#
# Epoch 00105: val_my_iou_metric did not improve from 0.78250
# Epoch 106/200
#  - 65s - loss: 0.0647 - acc: 0.9777 - my_iou_metric: 0.8632 - val_loss: 0.3488 - val_acc: 0.9424 - val_my_iou_metric: 0.7669
#
# Epoch 00106: val_my_iou_metric did not improve from 0.78250
# Epoch 107/200
#  - 65s - loss: 0.0651 - acc: 0.9775 - my_iou_metric: 0.8622 - val_loss: 0.3503 - val_acc: 0.9421 - val_my_iou_metric: 0.7746
#
# Epoch 00107: val_my_iou_metric did not improve from 0.78250
# Epoch 108/200
#  - 65s - loss: 0.0645 - acc: 0.9777 - my_iou_metric: 0.8624 - val_loss: 0.3493 - val_acc: 0.9419 - val_my_iou_metric: 0.7665
#
# Epoch 00108: val_my_iou_metric did not improve from 0.78250
# Epoch 109/200
#  - 65s - loss: 0.0643 - acc: 0.9777 - my_iou_metric: 0.8617 - val_loss: 0.3522 - val_acc: 0.9420 - val_my_iou_metric: 0.7677
#
# Epoch 00109: val_my_iou_metric did not improve from 0.78250
# Epoch 110/200
#  - 65s - loss: 0.0634 - acc: 0.9778 - my_iou_metric: 0.8651 - val_loss: 0.3495 - val_acc: 0.9424 - val_my_iou_metric: 0.7685
#
# Epoch 00110: val_my_iou_metric did not improve from 0.78250
# Epoch 111/200
#  - 65s - loss: 0.0633 - acc: 0.9778 - my_iou_metric: 0.8652 - val_loss: 0.3506 - val_acc: 0.9425 - val_my_iou_metric: 0.7699
#
# Epoch 00111: val_my_iou_metric did not improve from 0.78250
# Epoch 112/200
#  - 65s - loss: 0.0639 - acc: 0.9778 - my_iou_metric: 0.8630 - val_loss: 0.3481 - val_acc: 0.9423 - val_my_iou_metric: 0.7706
#
# Epoch 00112: val_my_iou_metric did not improve from 0.78250
# Epoch 113/200
#  - 65s - loss: 0.0627 - acc: 0.9780 - my_iou_metric: 0.8645 - val_loss: 0.3483 - val_acc: 0.9421 - val_my_iou_metric: 0.7708
#
# Epoch 00113: val_my_iou_metric did not improve from 0.78250
# Epoch 114/200
#  - 65s - loss: 0.0632 - acc: 0.9779 - my_iou_metric: 0.8665 - val_loss: 0.3506 - val_acc: 0.9428 - val_my_iou_metric: 0.7671
#
# Epoch 00114: val_my_iou_metric did not improve from 0.78250
# Epoch 115/200
#  - 65s - loss: 0.0626 - acc: 0.9779 - my_iou_metric: 0.8643 - val_loss: 0.3517 - val_acc: 0.9421 - val_my_iou_metric: 0.7712
#
# Epoch 00115: val_my_iou_metric did not improve from 0.78250
# Epoch 116/200
#  - 65s - loss: 0.0616 - acc: 0.9781 - my_iou_metric: 0.8683 - val_loss: 0.3541 - val_acc: 0.9420 - val_my_iou_metric: 0.7689
#
# Epoch 00116: val_my_iou_metric did not improve from 0.78250
# Epoch 117/200
#  - 65s - loss: 0.0612 - acc: 0.9782 - my_iou_metric: 0.8670 - val_loss: 0.3576 - val_acc: 0.9423 - val_my_iou_metric: 0.7705
#
# Epoch 00117: val_my_iou_metric did not improve from 0.78250
# Epoch 118/200
#  - 65s - loss: 0.0612 - acc: 0.9782 - my_iou_metric: 0.8656 - val_loss: 0.3523 - val_acc: 0.9423 - val_my_iou_metric: 0.7724
#
# Epoch 00118: val_my_iou_metric did not improve from 0.78250
# Epoch 119/200
#  - 65s - loss: 0.0609 - acc: 0.9782 - my_iou_metric: 0.8687 - val_loss: 0.3530 - val_acc: 0.9420 - val_my_iou_metric: 0.7696
#
# Epoch 00119: val_my_iou_metric did not improve from 0.78250
# Epoch 120/200
#  - 65s - loss: 0.0609 - acc: 0.9783 - my_iou_metric: 0.8697 - val_loss: 0.3545 - val_acc: 0.9420 - val_my_iou_metric: 0.7678
#
# Epoch 00120: val_my_iou_metric did not improve from 0.78250
# Epoch 121/200
#  - 65s - loss: 0.0614 - acc: 0.9782 - my_iou_metric: 0.8660 - val_loss: 0.3560 - val_acc: 0.9420 - val_my_iou_metric: 0.7718
#
# Epoch 00121: val_my_iou_metric did not improve from 0.78250
# Epoch 122/200
#  - 65s - loss: 0.0601 - acc: 0.9784 - my_iou_metric: 0.8688 - val_loss: 0.3552 - val_acc: 0.9424 - val_my_iou_metric: 0.7678
#
# Epoch 00122: val_my_iou_metric did not improve from 0.78250
# Epoch 123/200
#  - 65s - loss: 0.0601 - acc: 0.9783 - my_iou_metric: 0.8684 - val_loss: 0.3558 - val_acc: 0.9426 - val_my_iou_metric: 0.7686
#
# Epoch 00123: val_my_iou_metric did not improve from 0.78250
# Epoch 124/200
#  - 65s - loss: 0.0604 - acc: 0.9783 - my_iou_metric: 0.8657 - val_loss: 0.3591 - val_acc: 0.9421 - val_my_iou_metric: 0.7670
#
# Epoch 00124: val_my_iou_metric did not improve from 0.78250
# Epoch 125/200
#  - 65s - loss: 0.0610 - acc: 0.9783 - my_iou_metric: 0.8662 - val_loss: 0.3551 - val_acc: 0.9426 - val_my_iou_metric: 0.7616
#
# Epoch 00125: val_my_iou_metric did not improve from 0.78250
# Epoch 126/200
#  - 65s - loss: 0.0587 - acc: 0.9786 - my_iou_metric: 0.8708 - val_loss: 0.3588 - val_acc: 0.9421 - val_my_iou_metric: 0.7648
#
# Epoch 00126: val_my_iou_metric did not improve from 0.78250
# Epoch 127/200
#  - 65s - loss: 0.0589 - acc: 0.9786 - my_iou_metric: 0.8698 - val_loss: 0.3578 - val_acc: 0.9424 - val_my_iou_metric: 0.7671
#
# Epoch 00127: val_my_iou_metric did not improve from 0.78250
# Epoch 128/200
#  - 65s - loss: 0.0581 - acc: 0.9787 - my_iou_metric: 0.8688 - val_loss: 0.3586 - val_acc: 0.9419 - val_my_iou_metric: 0.7661
#
# Epoch 00128: val_my_iou_metric did not improve from 0.78250
# Epoch 129/200
#  - 65s - loss: 0.0582 - acc: 0.9786 - my_iou_metric: 0.8702 - val_loss: 0.3642 - val_acc: 0.9416 - val_my_iou_metric: 0.7651
#
# Epoch 00129: val_my_iou_metric did not improve from 0.78250
# Epoch 130/200
#  - 65s - loss: 0.0584 - acc: 0.9786 - my_iou_metric: 0.8672 - val_loss: 0.3624 - val_acc: 0.9421 - val_my_iou_metric: 0.7689
#
# Epoch 00130: val_my_iou_metric did not improve from 0.78250
# Epoch 131/200
#  - 65s - loss: 0.0573 - acc: 0.9789 - my_iou_metric: 0.8715 - val_loss: 0.3603 - val_acc: 0.9421 - val_my_iou_metric: 0.7701
#
# Epoch 00131: val_my_iou_metric did not improve from 0.78250
# Epoch 132/200
#  - 65s - loss: 0.0580 - acc: 0.9787 - my_iou_metric: 0.8681 - val_loss: 0.3644 - val_acc: 0.9418 - val_my_iou_metric: 0.7700
#
# Epoch 00132: val_my_iou_metric did not improve from 0.78250
# Epoch 133/200
#  - 65s - loss: 0.0578 - acc: 0.9787 - my_iou_metric: 0.8700 - val_loss: 0.3665 - val_acc: 0.9417 - val_my_iou_metric: 0.7699
#
# Epoch 00133: val_my_iou_metric did not improve from 0.78250
# Epoch 134/200
#  - 65s - loss: 0.0572 - acc: 0.9789 - my_iou_metric: 0.8727 - val_loss: 0.3676 - val_acc: 0.9419 - val_my_iou_metric: 0.7685
#
# Epoch 00134: val_my_iou_metric did not improve from 0.78250
# Epoch 135/200
#  - 65s - loss: 0.0567 - acc: 0.9790 - my_iou_metric: 0.8718 - val_loss: 0.3638 - val_acc: 0.9421 - val_my_iou_metric: 0.7665
#
# Epoch 00135: val_my_iou_metric did not improve from 0.78250
# Epoch 136/200
#  - 65s - loss: 0.0572 - acc: 0.9788 - my_iou_metric: 0.8707 - val_loss: 0.3661 - val_acc: 0.9419 - val_my_iou_metric: 0.7688
#
# Epoch 00136: val_my_iou_metric did not improve from 0.78250
# Epoch 137/200
#  - 65s - loss: 0.0560 - acc: 0.9790 - my_iou_metric: 0.8741 - val_loss: 0.3648 - val_acc: 0.9423 - val_my_iou_metric: 0.7690
#
# Epoch 00137: val_my_iou_metric did not improve from 0.78250
# Epoch 138/200
#  - 65s - loss: 0.0565 - acc: 0.9789 - my_iou_metric: 0.8726 - val_loss: 0.3684 - val_acc: 0.9419 - val_my_iou_metric: 0.7686
#
# Epoch 00138: val_my_iou_metric did not improve from 0.78250
# Epoch 139/200
#  - 65s - loss: 0.0562 - acc: 0.9790 - my_iou_metric: 0.8703 - val_loss: 0.3662 - val_acc: 0.9418 - val_my_iou_metric: 0.7694
#
# Epoch 00139: val_my_iou_metric did not improve from 0.78250
# Epoch 140/200
#  - 65s - loss: 0.0553 - acc: 0.9792 - my_iou_metric: 0.8754 - val_loss: 0.3677 - val_acc: 0.9420 - val_my_iou_metric: 0.7697
#
# Epoch 00140: val_my_iou_metric did not improve from 0.78250
# Epoch 141/200
#  - 65s - loss: 0.0555 - acc: 0.9791 - my_iou_metric: 0.8718 - val_loss: 0.3668 - val_acc: 0.9418 - val_my_iou_metric: 0.7658
#
# Epoch 00141: val_my_iou_metric did not improve from 0.78250
# Epoch 142/200
#  - 65s - loss: 0.0554 - acc: 0.9791 - my_iou_metric: 0.8746 - val_loss: 0.3639 - val_acc: 0.9424 - val_my_iou_metric: 0.7708
#
# Epoch 00142: val_my_iou_metric did not improve from 0.78250
# Epoch 143/200
#  - 65s - loss: 0.0549 - acc: 0.9792 - my_iou_metric: 0.8759 - val_loss: 0.3695 - val_acc: 0.9422 - val_my_iou_metric: 0.7696
#
# Epoch 00143: val_my_iou_metric did not improve from 0.78250
# Epoch 144/200
#  - 65s - loss: 0.0551 - acc: 0.9792 - my_iou_metric: 0.8748 - val_loss: 0.3671 - val_acc: 0.9424 - val_my_iou_metric: 0.7675
#
# Epoch 00144: val_my_iou_metric did not improve from 0.78250
# Epoch 145/200
#  - 65s - loss: 0.0551 - acc: 0.9792 - my_iou_metric: 0.8751 - val_loss: 0.3663 - val_acc: 0.9423 - val_my_iou_metric: 0.7703
#
# Epoch 00145: val_my_iou_metric did not improve from 0.78250
# Epoch 146/200
#  - 65s - loss: 0.0543 - acc: 0.9794 - my_iou_metric: 0.8765 - val_loss: 0.3707 - val_acc: 0.9424 - val_my_iou_metric: 0.7681
#
# Epoch 00146: val_my_iou_metric did not improve from 0.78250
# Epoch 147/200
#  - 65s - loss: 0.0540 - acc: 0.9794 - my_iou_metric: 0.8778 - val_loss: 0.3716 - val_acc: 0.9419 - val_my_iou_metric: 0.7691
#
# Epoch 00147: val_my_iou_metric did not improve from 0.78250
# Epoch 148/200
#  - 65s - loss: 0.0544 - acc: 0.9793 - my_iou_metric: 0.8759 - val_loss: 0.3720 - val_acc: 0.9421 - val_my_iou_metric: 0.7695
#
# Epoch 00148: val_my_iou_metric did not improve from 0.78250
# Epoch 149/200
#  - 65s - loss: 0.0541 - acc: 0.9793 - my_iou_metric: 0.8738 - val_loss: 0.3732 - val_acc: 0.9423 - val_my_iou_metric: 0.7699
#
# Epoch 00149: val_my_iou_metric did not improve from 0.78250
# Epoch 150/200
#  - 65s - loss: 0.0539 - acc: 0.9794 - my_iou_metric: 0.8765 - val_loss: 0.3705 - val_acc: 0.9423 - val_my_iou_metric: 0.7696
#
# Epoch 00150: val_my_iou_metric did not improve from 0.78250
# Epoch 151/200
#  - 65s - loss: 0.0541 - acc: 0.9794 - my_iou_metric: 0.8763 - val_loss: 0.3658 - val_acc: 0.9425 - val_my_iou_metric: 0.7677
#
# Epoch 00151: val_my_iou_metric did not improve from 0.78250
# Epoch 152/200
#  - 65s - loss: 0.0542 - acc: 0.9794 - my_iou_metric: 0.8746 - val_loss: 0.3716 - val_acc: 0.9420 - val_my_iou_metric: 0.7697
#
# Epoch 00152: val_my_iou_metric did not improve from 0.78250
# Epoch 153/200
#  - 65s - loss: 0.0530 - acc: 0.9795 - my_iou_metric: 0.8774 - val_loss: 0.3742 - val_acc: 0.9419 - val_my_iou_metric: 0.7686
#
# Epoch 00153: val_my_iou_metric did not improve from 0.78250
# Epoch 154/200
#  - 65s - loss: 0.0529 - acc: 0.9796 - my_iou_metric: 0.8783 - val_loss: 0.3756 - val_acc: 0.9420 - val_my_iou_metric: 0.7680
#
# Epoch 00154: val_my_iou_metric did not improve from 0.78250
# Epoch 155/200
#  - 65s - loss: 0.0528 - acc: 0.9795 - my_iou_metric: 0.8775 - val_loss: 0.3765 - val_acc: 0.9417 - val_my_iou_metric: 0.7673
#
# Epoch 00155: val_my_iou_metric did not improve from 0.78250
# Epoch 156/200
#  - 65s - loss: 0.0521 - acc: 0.9797 - my_iou_metric: 0.8786 - val_loss: 0.3765 - val_acc: 0.9419 - val_my_iou_metric: 0.7660
#
# Epoch 00156: val_my_iou_metric did not improve from 0.78250
# Epoch 157/200
#  - 65s - loss: 0.0516 - acc: 0.9797 - my_iou_metric: 0.8799 - val_loss: 0.3789 - val_acc: 0.9415 - val_my_iou_metric: 0.7679
#
# Epoch 00157: val_my_iou_metric did not improve from 0.78250
# Epoch 158/200
#  - 65s - loss: 0.0521 - acc: 0.9796 - my_iou_metric: 0.8786 - val_loss: 0.3770 - val_acc: 0.9417 - val_my_iou_metric: 0.7664
#
# Epoch 00158: val_my_iou_metric did not improve from 0.78250
# Epoch 159/200
#  - 65s - loss: 0.0514 - acc: 0.9798 - my_iou_metric: 0.8819 - val_loss: 0.3817 - val_acc: 0.9417 - val_my_iou_metric: 0.7665
#
# Epoch 00159: val_my_iou_metric did not improve from 0.78250
# Epoch 160/200
#  - 65s - loss: 0.0517 - acc: 0.9797 - my_iou_metric: 0.8811 - val_loss: 0.3810 - val_acc: 0.9416 - val_my_iou_metric: 0.7664
#
# Epoch 00160: val_my_iou_metric did not improve from 0.78250
# Epoch 161/200
#  - 65s - loss: 0.0507 - acc: 0.9799 - my_iou_metric: 0.8795 - val_loss: 0.3788 - val_acc: 0.9417 - val_my_iou_metric: 0.7665
# Epoch 00161: val_my_iou_metric did not improve from 0.78250
# Epoch 162/200
#  - 65s - loss: 0.0508 - acc: 0.9799 - my_iou_metric: 0.8788 - val_loss: 0.3822 - val_acc: 0.9414 - val_my_iou_metric: 0.7649
#
# Epoch 00162: val_my_iou_metric did not improve from 0.78250
# Epoch 163/200
#  - 65s - loss: 0.0505 - acc: 0.9799 - my_iou_metric: 0.8829 - val_loss: 0.3839 - val_acc: 0.9413 - val_my_iou_metric: 0.7650
#
# Epoch 00163: val_my_iou_metric did not improve from 0.78250
# Epoch 164/200
#  - 65s - loss: 0.0504 - acc: 0.9799 - my_iou_metric: 0.8827 - val_loss: 0.3818 - val_acc: 0.9420 - val_my_iou_metric: 0.7632
#
# Epoch 00164: val_my_iou_metric did not improve from 0.78250
# Epoch 165/200
#  - 65s - loss: 0.0504 - acc: 0.9799 - my_iou_metric: 0.8818 - val_loss: 0.3844 - val_acc: 0.9418 - val_my_iou_metric: 0.7622
#
# Epoch 00165: val_my_iou_metric did not improve from 0.78250
# Epoch 166/200
#  - 65s - loss: 0.0502 - acc: 0.9800 - my_iou_metric: 0.8810 - val_loss: 0.3852 - val_acc: 0.9417 - val_my_iou_metric: 0.7670
#
# Epoch 00166: val_my_iou_metric did not improve from 0.78250
# Epoch 167/200
#  - 65s - loss: 0.0493 - acc: 0.9801 - my_iou_metric: 0.8835 - val_loss: 0.3801 - val_acc: 0.9419 - val_my_iou_metric: 0.7606
#
# Epoch 00167: val_my_iou_metric did not improve from 0.78250
# Epoch 168/200
#  - 65s - loss: 0.0496 - acc: 0.9801 - my_iou_metric: 0.8827 - val_loss: 0.3835 - val_acc: 0.9420 - val_my_iou_metric: 0.7615
#
# Epoch 00168: val_my_iou_metric did not improve from 0.78250
# Epoch 169/200
#  - 65s - loss: 0.0498 - acc: 0.9801 - my_iou_metric: 0.8803 - val_loss: 0.3873 - val_acc: 0.9419 - val_my_iou_metric: 0.7661
#
# Epoch 00169: val_my_iou_metric did not improve from 0.78250
# Epoch 170/200
#  - 65s - loss: 0.0490 - acc: 0.9802 - my_iou_metric: 0.8847 - val_loss: 0.3834 - val_acc: 0.9423 - val_my_iou_metric: 0.7644
#
# Epoch 00170: val_my_iou_metric did not improve from 0.78250
# Epoch 171/200
#  - 65s - loss: 0.0505 - acc: 0.9800 - my_iou_metric: 0.8827 - val_loss: 0.3881 - val_acc: 0.9417 - val_my_iou_metric: 0.7672
#
# Epoch 00171: val_my_iou_metric did not improve from 0.78250
# Epoch 172/200
#  - 65s - loss: 0.0491 - acc: 0.9802 - my_iou_metric: 0.8858 - val_loss: 0.3893 - val_acc: 0.9415 - val_my_iou_metric: 0.7698
#
# Epoch 00172: val_my_iou_metric did not improve from 0.78250
# Epoch 173/200
#  - 65s - loss: 0.0494 - acc: 0.9802 - my_iou_metric: 0.8852 - val_loss: 0.3866 - val_acc: 0.9417 - val_my_iou_metric: 0.7656
#
# Epoch 00173: val_my_iou_metric did not improve from 0.78250
# Epoch 174/200
#  - 65s - loss: 0.0484 - acc: 0.9803 - my_iou_metric: 0.8871 - val_loss: 0.3902 - val_acc: 0.9420 - val_my_iou_metric: 0.7656
#
# Epoch 00174: val_my_iou_metric did not improve from 0.78250
# Epoch 175/200
#  - 65s - loss: 0.0491 - acc: 0.9802 - my_iou_metric: 0.8843 - val_loss: 0.3844 - val_acc: 0.9424 - val_my_iou_metric: 0.7619
#
# Epoch 00175: val_my_iou_metric did not improve from 0.78250
# Epoch 176/200
#  - 65s - loss: 0.0488 - acc: 0.9802 - my_iou_metric: 0.8855 - val_loss: 0.3915 - val_acc: 0.9420 - val_my_iou_metric: 0.7660
#
# Epoch 00176: val_my_iou_metric did not improve from 0.78250
# Epoch 177/200
#  - 65s - loss: 0.0481 - acc: 0.9803 - my_iou_metric: 0.8861 - val_loss: 0.3886 - val_acc: 0.9422 - val_my_iou_metric: 0.7679
#
# Epoch 00177: val_my_iou_metric did not improve from 0.78250
# Epoch 178/200
#  - 65s - loss: 0.0478 - acc: 0.9804 - my_iou_metric: 0.8865 - val_loss: 0.3933 - val_acc: 0.9420 - val_my_iou_metric: 0.7667
#
# Epoch 00178: val_my_iou_metric did not improve from 0.78250
# Epoch 179/200
#  - 65s - loss: 0.0484 - acc: 0.9803 - my_iou_metric: 0.8869 - val_loss: 0.3948 - val_acc: 0.9414 - val_my_iou_metric: 0.7685
#
# Epoch 00179: val_my_iou_metric did not improve from 0.78250
# Epoch 180/200
#  - 65s - loss: 0.0474 - acc: 0.9804 - my_iou_metric: 0.8885 - val_loss: 0.3929 - val_acc: 0.9417 - val_my_iou_metric: 0.7658
#
# Epoch 00180: val_my_iou_metric did not improve from 0.78250
# Epoch 181/200
#  - 65s - loss: 0.0483 - acc: 0.9803 - my_iou_metric: 0.8862 - val_loss: 0.3917 - val_acc: 0.9421 - val_my_iou_metric: 0.7660
#
# Epoch 00181: val_my_iou_metric did not improve from 0.78250
# Epoch 182/200
#  - 65s - loss: 0.0471 - acc: 0.9805 - my_iou_metric: 0.8890 - val_loss: 0.3919 - val_acc: 0.9421 - val_my_iou_metric: 0.7590
#
# Epoch 00182: val_my_iou_metric did not improve from 0.78250
# Epoch 183/200
#  - 65s - loss: 0.0471 - acc: 0.9805 - my_iou_metric: 0.8873 - val_loss: 0.3913 - val_acc: 0.9421 - val_my_iou_metric: 0.7631
#
# Epoch 00183: val_my_iou_metric did not improve from 0.78250
# Epoch 184/200
#  - 65s - loss: 0.0470 - acc: 0.9805 - my_iou_metric: 0.8907 - val_loss: 0.3923 - val_acc: 0.9423 - val_my_iou_metric: 0.7647
#
# Epoch 00184: val_my_iou_metric did not improve from 0.78250
# Epoch 185/200
#  - 65s - loss: 0.0469 - acc: 0.9805 - my_iou_metric: 0.8856 - val_loss: 0.3931 - val_acc: 0.9422 - val_my_iou_metric: 0.7653
#
# Epoch 00185: val_my_iou_metric did not improve from 0.78250
# Epoch 186/200
#  - 65s - loss: 0.0473 - acc: 0.9804 - my_iou_metric: 0.8872 - val_loss: 0.3949 - val_acc: 0.9424 - val_my_iou_metric: 0.7640
#
# Epoch 00186: val_my_iou_metric did not improve from 0.78250
# Epoch 187/200
#  - 65s - loss: 0.0469 - acc: 0.9805 - my_iou_metric: 0.8897 - val_loss: 0.3961 - val_acc: 0.9417 - val_my_iou_metric: 0.7652
#
# Epoch 00187: val_my_iou_metric did not improve from 0.78250
# Epoch 188/200
#  - 65s - loss: 0.0467 - acc: 0.9805 - my_iou_metric: 0.8887 - val_loss: 0.3936 - val_acc: 0.9422 - val_my_iou_metric: 0.7634
#
# Epoch 00188: val_my_iou_metric did not improve from 0.78250
# Epoch 189/200
#  - 65s - loss: 0.0467 - acc: 0.9805 - my_iou_metric: 0.8890 - val_loss: 0.3942 - val_acc: 0.9420 - val_my_iou_metric: 0.7632
#
# Epoch 00189: val_my_iou_metric did not improve from 0.78250
# Epoch 190/200
#  - 65s - loss: 0.0463 - acc: 0.9806 - my_iou_metric: 0.8884 - val_loss: 0.3965 - val_acc: 0.9421 - val_my_iou_metric: 0.7646
#
# Epoch 00190: val_my_iou_metric did not improve from 0.78250
# Epoch 191/200
#  - 65s - loss: 0.0458 - acc: 0.9807 - my_iou_metric: 0.8905 - val_loss: 0.3971 - val_acc: 0.9420 - val_my_iou_metric: 0.7619
#
# Epoch 00191: val_my_iou_metric did not improve from 0.78250
# Epoch 192/200
#  - 65s - loss: 0.0459 - acc: 0.9806 - my_iou_metric: 0.8925 - val_loss: 0.3991 - val_acc: 0.9420 - val_my_iou_metric: 0.7597
#
# Epoch 00192: val_my_iou_metric did not improve from 0.78250
# Epoch 193/200
#  - 65s - loss: 0.0458 - acc: 0.9807 - my_iou_metric: 0.8911 - val_loss: 0.4023 - val_acc: 0.9419 - val_my_iou_metric: 0.7635
#
# Epoch 00193: val_my_iou_metric did not improve from 0.78250
# Epoch 194/200
#  - 65s - loss: 0.0455 - acc: 0.9807 - my_iou_metric: 0.8940 - val_loss: 0.4016 - val_acc: 0.9417 - val_my_iou_metric: 0.7590
#
# Epoch 00194: val_my_iou_metric did not improve from 0.78250
# Epoch 195/200
#  - 65s - loss: 0.0455 - acc: 0.9808 - my_iou_metric: 0.8915 - val_loss: 0.4039 - val_acc: 0.9418 - val_my_iou_metric: 0.7639
#
# Epoch 00195: val_my_iou_metric did not improve from 0.78250
# Epoch 196/200
#  - 65s - loss: 0.0450 - acc: 0.9808 - my_iou_metric: 0.8940 - val_loss: 0.4059 - val_acc: 0.9417 - val_my_iou_metric: 0.7621
#
# Epoch 00196: val_my_iou_metric did not improve from 0.78250
# Epoch 197/200
#  - 65s - loss: 0.0453 - acc: 0.9807 - my_iou_metric: 0.8903 - val_loss: 0.4044 - val_acc: 0.9411 - val_my_iou_metric: 0.7609
#
# Epoch 00197: val_my_iou_metric did not improve from 0.78250
# Epoch 198/200
#  - 65s - loss: 0.0446 - acc: 0.9809 - my_iou_metric: 0.8935 - val_loss: 0.4051 - val_acc: 0.9418 - val_my_iou_metric: 0.7635
#
# Epoch 00198: val_my_iou_metric did not improve from 0.78250
# Epoch 199/200
#  - 65s - loss: 0.0446 - acc: 0.9809 - my_iou_metric: 0.8938 - val_loss: 0.4016 - val_acc: 0.9422 - val_my_iou_metric: 0.7586
#
# Epoch 00199: val_my_iou_metric did not improve from 0.78250
# Epoch 200/200
#  - 65s - loss: 0.0443 - acc: 0.9809 - my_iou_metric: 0.8939 - val_loss: 0.3982 - val_acc: 0.9425 - val_my_iou_metric: 0.7566
#
# Epoch 00200: val_my_iou_metric did not improve from 0.78250

# %%
del ids_train, x_train, y_train, cov_train,depth_train,depths_df,depth_test
gc.collect()
# Out:
# 7

# %%
plt.plot(history.history['my_iou_metric'][1:])
plt.plot(history.history['val_my_iou_metric'][1:])
plt.title('model loss')
plt.ylabel('val_my_iou_metric')
plt.xlabel('epoch')
plt.legend(['train','Validation'], loc='upper left')
plt.show()

# %%
# model = load_model("./keras.model")
# Load best model
model.load_weights('./keras.model')

# %% [markdown]
# # Predict the validation set to do a sanity check

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test1 = model.predict([x_test]).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict([x_test_reflect]).reshape(-1, img_size_target, img_size_target)
    preds_test2 = np.array([ np.fliplr(x) for x in preds_test2_refect] )
    preds_avg = (preds_test1 +preds_test2)/2
    return preds_avg

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
preds_valid = np.array([downsample(x) for x in preds_valid])
y_valid_ori = np.array([downsample(x) for x in y_valid])

# %%
max_images = 60
grid_width = 15
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width, grid_height))
for i, idx in enumerate(ids_valid[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    pred = preds_valid[i]
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.imshow(pred, alpha=0.3, cmap="OrRd")
    ax.text(1, img_size_ori-1, train_df.loc[idx].z, color="black")
    ax.text(img_size_ori - 1, 1, round(train_df.loc[idx].coverage, 2), color="black", ha="right", va="top")
    ax.text(1, 1, train_df.loc[idx].coverage_class, color="black", ha="left", va="top")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.suptitle("Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")
# Out:
# Text(0.5,0.98,'Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth')

# %% [markdown]
# # Scoring

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in
    
    true_objects = 2
    pred_objects = 2

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model
thresholds = np.linspace(0.3, 0.7, 31)
ious = np.array([iou_metric_batch(y_valid_ori, np.int32(preds_valid > threshold)) for threshold in tqdm_notebook(thresholds)])
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))

# %%
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
threshold_best
# Out:
# 0.5933333333333333

# %% [markdown]
# # Another sanity check with adjusted threshold

# %%
max_images = 60
grid_width = 15
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width, grid_height))
for i, idx in enumerate(ids_valid[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    pred = preds_valid[i]
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.imshow(np.array(np.round(pred > threshold_best), dtype=np.float32), alpha=0.3, cmap="OrRd")
    ax.text(1, img_size_ori-1, train_df.loc[idx].z, color="black")
    ax.text(img_size_ori - 1, 1, round(train_df.loc[idx].coverage, 2), color="black", ha="right", va="top")
    ax.text(1, 1, train_df.loc[idx].coverage_class, color="black", ha="left", va="top")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.suptitle("Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")
# Out:
# Text(0.5,0.98,'Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth')

# %% [markdown]
# # Submission

# %%
del x_valid, y_valid,preds_valid,y_valid_ori,train_df
gc.collect()
# Out:
# 2921

# %%
def rle_encode(im):
    pixels = im.flatten(order = 'F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

batch_size = 500
preds_test = []
i = 0
while i < test_df.shape[0]:
    print('Images Processed:',i)
    index_val = test_df.index[i:i+batch_size]
    depth_val = test_df.z[i:i+batch_size]
    x_test = np.array([upsample(np.array(load_img("../data/test/images/{}.png".format(idx), grayscale=True))) / 255 for idx in (index_val)]).reshape(-1, img_size_target, img_size_target, 1)
    x_test = np.repeat(x_test,3,axis=3)
    preds_test_temp = predict_result(model,x_test,img_size_target)
    if i==0:
        preds_test = preds_test_temp
    else:
        preds_test = np.concatenate([preds_test,preds_test_temp],axis=0)
#     print(preds_test.shape)
    i += batch_size
# Out:
# Images Processed: 0
# Images Processed: 500
# Images Processed: 1000
# Images Processed: 1500
# Images Processed: 2000
# Images Processed: 2500
# Images Processed: 3000
# Images Processed: 3500
# Images Processed: 4000
# Images Processed: 4500
# Images Processed: 5000
# Images Processed: 5500
# Images Processed: 6000
# Images Processed: 6500
# Images Processed: 7000
# Images Processed: 7500
# Images Processed: 8000
# Images Processed: 8500
# Images Processed: 9000
# Images Processed: 9500
# Images Processed: 10000
# Images Processed: 10500
# Images Processed: 11000
# Images Processed: 11500
# Images Processed: 12000
# Images Processed: 12500
# Images Processed: 13000
# Images Processed: 13500
# Images Processed: 14000
# Images Processed: 14500
# Images Processed: 15000
# Images Processed: 15500
# Images Processed: 16000
# Images Processed: 16500
# Images Processed: 17000
# Images Processed: 17500

# %%
del x_test,preds_test_temp
gc.collect()
# Out:
# 0

# %%
import time
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# Usedtime = 20.021215200424194 s

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv('resnet50_pretrained_submission.csv')
